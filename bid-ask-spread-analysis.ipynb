# %%
import pandas as pd 
import numpy as np
import json
import os
from datetime import datetime

# %%
file_array = []
dates = []


for file in os.listdir("/Users/anthony/Desktop/slipping-and-sliding/all-exchanges/"):
    if file.endswith("kraken_orderbook.json"):
        file_array.append(os.path.join("/Users/anthony/Desktop/slipping-and-sliding/all-exchanges/", file))


for file in file_array:
    date = file.split('/')[6].split('_')[0]
    dates.append(date)

# %%
slippage = []
slippage_pairs = []
currencies = []

for index, file in enumerate(file_array):
    print(file)
    try:
        with open(file, encoding='utf-8') as data_file:
            dataset = json.loads(data_file.read())
        for pair in dataset: 
            if (len(dataset[pair]['asks']) > 5 and len(dataset[pair]['bids']) > 5):
                currency = {}
                currency['Pair'] = pair
                currency['Asks'] = dataset[pair]['asks']
                currency['Bids'] = dataset[pair]['bids']
                currency['Date'] = dates[index]
                currencies.append(currency)
    except:
        continue


        
df = pd.DataFrame(currencies)

pair_dict = {}


for pair, value in dict(df['Pair'].value_counts()).items():
    trading_currency = pair.split('/')[1]
    if trading_currency in pair_dict.keys():
        pair_dict[trading_currency] += value 
    else:
        pair_dict[trading_currency] = value

pair_dict

sorted(pair_dict.items(), key=lambda x: x[0])


#assume PAX TUSD USDC USDS USDT are 1 to 1 

#Find How much BNB BTC ETH XRP you can get for 10k USD

bitcoin_prices_in_usd = {}
eth_prices_in_usd = {}
bnb_prices_in_usd = {}
xrp_prices_in_usd = {}


for entry in currencies:
    if entry['Pair'] == 'BTC/USDT':
        bitcoin_prices_in_usd[(entry['Date'])] = (entry['Asks'][0][0] + entry['Bids'][0][0]) / 2
    if entry['Pair'] == 'ETH/USDT':
        eth_prices_in_usd[(entry['Date'])] = (entry['Asks'][0][0] + entry['Bids'][0][0]) / 2
    if entry['Pair'] == 'BNB/USDT':
        bnb_prices_in_usd[(entry['Date'])] = (entry['Asks'][0][0] + entry['Bids'][0][0]) / 2
    if entry['Pair'] == 'XRP/USDT':
        xrp_prices_in_usd[(entry['Date'])] = (entry['Asks'][0][0] + entry['Bids'][0][0]) / 2

def calc_slippage_asks(asks, amount):
    starting_amount = amount
    asking_price = asks[0][0]
    index = 0
    while starting_amount > 0:
        try:
            amount = asks[index][0] * asks[index][1]
            if starting_amount - amount < 0:
                break
            else:
                index +=1
        except:
            return 100

    return (asks[index][0] - asking_price) / asking_price


def calc_slippage_bids(bids, amount):
    starting_amount = amount
    bid_price = bids[0][0]
    index = 0
    while starting_amount > 0:
        try:
            amount = bids[index][0] * bids[index][1]
            if starting_amount - amount < 0:
                break
            else:
                index +=1
        except:
            return 100
    return (bids[index][0] - bid_price) / bid_price * 100


def calc_total_order_book_depth(date, bids_or_asks, pair):
    base_currency = pair.split('/')[1]
    total_depth = 0
    for bid_or_ask in bids_or_asks:
        if base_currency == 'BTC':
            total_depth += (bid_or_ask[0] * bitcoin_prices_in_usd[date] * bid_or_ask[1])
        elif base_currency == 'XRP':
            total_depth += (bid_or_ask[0] * xrp_prices_in_usd[date] * bid_or_ask[1])
        elif base_currency == 'BNB':
            total_depth += (bid_or_ask[0] * bnb_prices_in_usd[date] * bid_or_ask[1])
        elif base_currency == 'ETH':
            total_depth += (bid_or_ask[0] * eth_prices_in_usd[date] * bid_or_ask[1])
        else:
            total_depth += (bid_or_ask[0] * bid_or_ask[1])
    return total_depth

def calc_bid_ask_spread(bids, asks):
    spread = asks[0][0] - bids[0][0]
    percentage_spread = (spread / asks[0][0]) * 100
    return percentage_spread
# Out:
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552178707932_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552182460001_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552186214119_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552189968781_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552193722038_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552197476659_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552201234381_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552204992202_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552208750872_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552212508672_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552216262749_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552220019119_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552223767918_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552227537698_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552231293904_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552235064368_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552238819983_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552242592836_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552246351499_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552250110119_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552253867842_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552257622119_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552261394455_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552265147507_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552268936007_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552272718119_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552276479792_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552280271696_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552284057884_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552287840747_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552291645621_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552295486005_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552299296734_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552303053944_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552306812507_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552310571402_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552314331910_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552318088757_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552321846921_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552325604963_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552329383825_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552333145631_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552336910014_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552340662445_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552344448963_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552348204958_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552351965819_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552355720497_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552359476447_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552363233769_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552366994970_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552370747987_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552374502064_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552378254554_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552382014952_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552385768387_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552389522555_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552393294270_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552397053647_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552400811863_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552404568815_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552408328771_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552412264822_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552416032797_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552419798699_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552423576510_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552427358871_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552431158119_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552434977167_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552438844963_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552442602602_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552446365262_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552450123412_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552453879369_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552457637038_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552461394566_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552465158563_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552468924543_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552472681726_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552476449630_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552480209305_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552483967024_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552487724916_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552491483765_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552495244379_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552499015708_kraken_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552502774781_kraken_orderbook.json

# %%
final_currencies = []

for index, currency in enumerate(currencies):
    currency_dict = {}
    bid_ask_spread = calc_bid_ask_spread(currency['Bids'], currency['Asks'])
    currency_dict['bid_ask_spread'] = bid_ask_spread
    currency_dict['date'] = currency['Date']
    currency_dict['pair'] = currency['Pair']
    currency_dict['ask_depth'] = calc_total_order_book_depth(currency['Date'], currency['Asks'],currency['Pair'])
    currency_dict['bid_depth'] = calc_total_order_book_depth(currency['Date'], currency['Bids'], currency['Pair'])
    final_currencies.append(currency_dict)



        
def convert_cmc_to_binance(row):
    if row.split('/')[0] == 'BCHABC':
        return 'BCH' + '/' + row.split('/')[1]
    elif row.split('/')[0] == 'BCHSV':
        return 'BSV' + '/' + row.split('/')[1]
    elif row.split('/')[0] == 'YOYO':
        return 'YOYOW' + '/' + row.split('/')[1]
    else:
        return row

volume_dict = {}

df_rank = pd.read_csv('/users/anthony/desktop/slipping-and-sliding/all-exchanges/volume_rank.csv')

spread_df = pd.DataFrame(final_currencies)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b924f113b1b4> in <module>()
#       7     currency_dict['date'] = currency['Date']
#       8     currency_dict['pair'] = currency['Pair']
# ----> 9     currency_dict['ask_depth'] = calc_total_order_book_depth(currency['Date'], currency['Asks'],currency['Pair'])
#      10     currency_dict['bid_depth'] = calc_total_order_book_depth(currency['Date'], currency['Bids'], currency['Pair'])
#      11     final_currencies.append(currency_dict)
#
# <ipython-input-4-c2968e5de7fd> in calc_total_order_book_depth(date, bids_or_asks, pair)
#     102             total_depth += (bid_or_ask[0] * bnb_prices_in_usd[date] * bid_or_ask[1])
#     103         elif base_currency == 'ETH':
# --> 104             total_depth += (bid_or_ask[0] * eth_prices_in_usd[date] * bid_or_ask[1])
#     105         else:
#     106             total_depth += (bid_or_ask[0] * bid_or_ask[1])
#
# KeyError: '1552178707932'

# %%
def gen_bins(max_value, increment):
    bins = [0]
    x = 0
    while x < max_value:
        x += increment
        bins.append(x)
    return bins
final_df = pd.merge(spread_df, df_rank, left_on='pair', right_on='pair', how='left')

final_df['total_order_depth'] = final_df['ask_depth'] + final_df['bid_depth']

median_df_rank = pd.DataFrame(final_df.groupby('pair').median()['total_order_depth'].rank(ascending=False).sort_values()).reset_index()

median_df_rank.columns = ['pair','median rank']

last_df = pd.merge(final_df, median_df_rank, left_on='pair', right_on='pair')


# %matplotlib inline

import seaborn as sns
import matplotlib as plt

last_df = final_df.groupby('pair').mean()[['bid_ask_spread', 'average_volume']]




no_outliers_df = last_df[(last_df['bid_ask_spread'] < last_df['bid_ask_spread'].quantile(.95)) & (last_df['bid_ask_spread'] > last_df['bid_ask_spread'].quantile(.05))].reset_index()


no_outliers_df['log_volume'] = np.log(no_outliers_df['average_volume'])

no_outliers_df['volume_rank'] = no_outliers_df['average_volume'].rank(ascending=True, pct=True)

no_outliers_df = no_outliers_df.sort_values('volume_rank', ascending=True)

no_outliers_df['volume_rank_bin'] = pd.cut(no_outliers_df['volume_rank'], gen_bins(no_outliers_df['volume_rank'].max(), 0.25))

no_outliers_df



g = sns.lmplot(data=no_outliers_df, x='log_volume', y='bid_ask_spread', hue='volume_rank_bin', fit_reg=False, size=12)
y = sns.regplot(x="log_volume", y="bid_ask_spread", data=no_outliers_df, scatter=False, ax=g.axes[0, 0])


fig = g.fig 

# Add a title to the Figure
g.set_xlabels('Log Transform Traffic Volume ', fontsize=18, weight='bold')
g.set_ylabels('Bid Ask Spread (%)', fontsize=18, weight='bold')

fig.suptitle("Relationship Bid-Ask Spread vs. Trading Volume on Binance", fontsize=24, weight='bold')
sns.set(rc={'figure.figsize':(11.7,8.27)})

plt.style.use('seaborn-poster')
plt.style.use('fivethirtyeight')
plt.rcParams['axes.edgecolor'] = '#ffffff'
plt.rcParams['axes.facecolor'] = '#ffffff'
plt.rcParams['figure.facecolor'] = '#ffffff'
plt.rcParams['patch.edgecolor'] = '#ffffff'
plt.rcParams['patch.facecolor'] = '#ffffff'
plt.rcParams['savefig.edgecolor'] = '#ffffff'
plt.rcParams['savefig.facecolor'] = '#ffffff'
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16

# %%
rank_1 = final_df[final_df['volume_rank']==1]
rank_50 = final_df[final_df['volume_rank']==50]

ax1 = sns.distplot(rank_1['bid_ask_spread'])
ax2 = sns.distplot(rank_50['bid_ask_spread'])



ax1.legend(['BTC/USD Rank 1 Volume','ZRX/BTC Rank 50 Volume'])
ax1.set_xlabel('Bid Ask Spread', fontsize=20, weight='bold')
ax1.set_ylabel('Density', fontsize=20, weight='bold')
ax1.set_title('Distribution of Bid-Ask Spreads 2 Trading Pairs on Binance', fontsize=30, weight='bold')

# %%
rank_50
# Out:
#           ask_depth  bid_ask_spread      bid_depth           date     pair  \
# 25     31980.524075        0.047476   40033.158708  1551627357881  ZRX/BTC
# 458    23421.385857        0.033344   33870.930512  1551695146658  ZRX/BTC
# 891    68626.739992        0.064516   37409.946257  1552065980946  ZRX/BTC
# 1330   47621.655297        0.079911   46187.075328  1552107331032  ZRX/BTC
# 1769   27568.118449        0.049759   81826.750542  1551691387119  ZRX/BTC
# 2202   26452.257549        0.015557   62175.263267  1551433626740  ZRX/BTC
# 2635   41409.877427        0.126422   44244.384668  1552174953488  ZRX/BTC
# 3074   47280.669295        0.094295   53456.091918  1552156177826  ZRX/BTC
# 3513   24844.900870        0.015518   62438.121908  1551478301522  ZRX/BTC
# 3946   42042.572726        0.015805   44497.414301  1552111083524  ZRX/BTC
# 4385   34860.103693        0.016295   51444.300706  1551672586518  ZRX/BTC
# 4818   50805.119256        0.049229  152586.877756  1551774300395  ZRX/BTC
# 5251   36310.037474        0.015473   58450.516798  1551353650312  ZRX/BTC
# 5684   68637.124339        0.049036   79871.342928  1552069744264  ZRX/BTC
# 6123   26421.048443        0.031013   78818.084973  1551482274077  ZRX/BTC
# 6556   34549.868413        0.173968   46889.115022  1551649977558  ZRX/BTC
# 6989   36867.838515        0.016404   28807.626832  1551725341359  ZRX/BTC
# 7422   36170.685800        0.015389   56922.860705  1551405380709  ZRX/BTC
# 7855   35709.205766        0.140889   37633.808126  1551521249080  ZRX/BTC
# 8288   33117.796462        0.016348   51140.704209  1551868395029  ZRX/BTC
# 8721   34600.659260        0.081367   38242.946406  1551883435872  ZRX/BTC
# 9154   35481.199700        0.078505   49106.936216  1551608090241  ZRX/BTC
# 9587   39501.031722        0.030253   43757.577393  1551494208281  ZRX/BTC
# 10020  41288.291069        0.142248   45904.321466  1552171202798  ZRX/BTC
# 10459  57022.176860        0.135461   58786.257251  1551318452211  ZRX/BTC
# 10892  24197.655527        0.061776   65401.268795  1551486220963  ZRX/BTC
# 11325  38734.635345        0.185300   76879.090671  1551413367716  ZRX/BTC
# 11758  27145.924309        0.032051   45972.313036  1552126108963  ZRX/BTC
# 12197  25840.980621        0.148834   36548.747200  1551702689398  ZRX/BTC
# 12630  56002.406869        0.033036   77606.320743  1552088548964  ZRX/BTC
# ...             ...             ...            ...            ...      ...
# 67741  37068.369491        0.078468   38645.383828  1551544897652  ZRX/BTC
